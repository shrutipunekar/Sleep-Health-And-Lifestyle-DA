# %%
import pandas as pd
a=pd.read_csv('data.csv')
print(a)
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %%
a = pd.read_csv('data.csv') 
b = a.dropna() 
print(b.to_string()) 
#saving the cleaned file 
b.to_csv('data1.csv', index=False)
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  Quality of Sleep  Physical Activity Level  Stress Level   BMI Category Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 3            4    Male   28  Sales Representative             5.9                 4                       30             8          Obese         140/90          85         3000    Sleep Apnea
# 4            5    Male   28  Sales Representative             5.9                 4                       30             8          Obese         140/90          85         3000    Sleep Apnea
# 5            6    Male   28     Software Engineer             5.9                 4                       30             8          Obese         140/90          85         3000       Insomnia
# 6            7    Male   29               Teacher             6.3                 6                       40             7          Obese         140/90          82         3500       Insomnia
# ...

# %%
a.head()
# Out:
#    Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0          4    Male   28  Sales Representative             5.9
# 1          5    Male   28  Sales Representative             5.9
# 2          6    Male   28     Software Engineer             5.9
# 3          7    Male   29               Teacher             6.3
# 4         17  Female   29                 Nurse             6.5
#
#    Quality of Sleep  Physical Activity Level  Stress Level   BMI Category  \
# 0                 4                       30             8          Obese
# 1                 4                       30             8          Obese
# 2                 4                       30             8          Obese
# 3                 6                       40             7          Obese
# 4                 5                       40             7  Normal Weight
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0         140/90          85         3000    Sleep Apnea
# ...

# %%
a.tail()
# Out:
#      Person ID  Gender  Age Occupation  Sleep Duration  Quality of Sleep  \
# 150        370  Female   59      Nurse             8.1                 9
# 151        371  Female   59      Nurse             8.0                 9
# 152        372  Female   59      Nurse             8.1                 9
# 153        373  Female   59      Nurse             8.1                 9
# 154        374  Female   59      Nurse             8.1                 9
#
#      Physical Activity Level  Stress Level BMI Category Blood Pressure  \
# 150                       75             3   Overweight         140/95
# 151                       75             3   Overweight         140/95
# 152                       75             3   Overweight         140/95
# 153                       75             3   Overweight         140/95
# 154                       75             3   Overweight         140/95
#
#      Heart Rate  Daily Steps Sleep Disorder
# 150          68         7000    Sleep Apnea
# ...

# %%
import pandas as pd 
df= pd.read_csv('data1.csv') 
print(df.duplicated())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 150    False
# 151    False
# 152    False
# 153    False
# 154    False
# Length: 155, dtype: bool

# %%
mean = df[['Age','Sleep Duration']].mean()
print(mean)
median = df[['Age','Sleep Duration']].median()
print(median)
mode = df[['Age','Sleep Duration']].mode()
print(mode)
# Out:
# Age               46.632258
# Sleep Duration     6.812258
# dtype: float64
# Age               45.0
# Sleep Duration     6.5
# dtype: float64
#    Age  Sleep Duration
# 0   44             6.5

# %%
a = pd.DataFrame(a) 
#Aggregating total  
b = a.groupby('Age')['Sleep Disorder'].count() 
print(b)
# Out:
# Age
# 28     3
# 29     4
# 30     2
# 31     1
# 33     1
# 34     2
# 35     1
# 36     4
# 38     2
# 39     2
# 41     1
# 42     3
# 43    19
# 44    28
# 45    11
# 48     3
# 49    10
# 50    18
# 51     3
# 52     6
# 53     1
# 55     2
# 57     8
# 58     6
# 59    14
# Name: Sleep Disorder, dtype: int64

# %%
a = pd.DataFrame(a) 
#Aggregating total  
b = a.groupby('Occupation')['Sleep Disorder'].count() 
print(b)
# Out:
# Occupation
# Accountant               7
# Doctor                   7
# Engineer                 6
# Lawyer                   5
# Nurse                   64
# Sales Representative     2
# Salesperson             30
# Scientist                2
# Software Engineer        1
# Teacher                 31
# Name: Sleep Disorder, dtype: int64

# %%
a=pd.DataFrame(a) 
#Aggregating total  
b = a.groupby('Gender')['Sleep Disorder'].count() 
print(b)
# Out:
# Gender
# Female    103
# Male       52
# Name: Sleep Disorder, dtype: int64

# %%
df=pd.DataFrame(df)
df.to_csv('newdata.csv', index=False)
